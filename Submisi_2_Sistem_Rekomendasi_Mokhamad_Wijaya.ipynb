# %% [markdown]
# # Data Loading

# %%
# !wget -c "https://storage.googleapis.com/kaggle-data-sets/1004280/5624361/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230730%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230730T143250Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..." \
  -O "archive.zip"

# %%
# !unzip archive.zip

# %%
import pandas as pd
import numpy as np

# %%
ds_books = pd.read_csv('Books.csv')
ds_ratings = pd.read_csv('Ratings.csv')
ds_users = pd.read_csv('Users.csv')
# Out:
# <ipython-input-4-41794279d53f>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds_books = pd.read_csv('Books.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Kondisi Data

# %%
print(
    f"Dataset books: jumlah data {ds_books.shape[0]} dengan {ds_books.shape[1]} kolom"
    + f"\nyang berisikan {list(ds_books.columns)}")
print(
    f"Dataset ratings: jumlah data {ds_ratings.shape[0]} dengan {ds_ratings.shape[1]} kolom"
    + f"\nyang berisikan {list(ds_ratings.columns)}")
print(
    f"Dataset users: jumlah data {ds_users.shape[0]} dengan {ds_users.shape[1]} kolom"
    + f"\nyang berisikan {list(ds_users.columns)}")
# Out:
# Dataset books: jumlah data 271360 dengan 8 kolom
# yang berisikan ['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M', 'Image-URL-L']
# Dataset ratings: jumlah data 1149780 dengan 3 kolom
# yang berisikan ['User-ID', 'ISBN', 'Book-Rating']
# Dataset users: jumlah data 278858 dengan 3 kolom
# yang berisikan ['User-ID', 'Location', 'Age']

# %%
ds_books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
ds_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ds_users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %% [markdown]
# ### Tipe Data

# %%
print("Tipe data pada dataset Books")
print(ds_books.info())
print("Tipe data pada dataset Ratings")
print(ds_ratings.info())
print("Tipe data pada dataset Users")
print(ds_users.info())
# Out:
# Tipe data pada dataset Books
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB
# None
# Tipe data pada dataset Ratings
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB
# None
# Tipe data pada dataset Users
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB
# None

# %% [markdown]
# ### Periksa Duplikasi Data

# %%
dpl_books = ds_books[ds_books.duplicated()]
print("jumlah baris duplikasi dataset Books: ", dpl_books.shape[0])
dpl_ratings = ds_ratings[ds_ratings.duplicated()]
print("jumlah baris duplikasi dataset Ratings: ", dpl_ratings.shape[0])
dpl_users = ds_users[ds_users.duplicated()]
print("jumlah baris duplikasi dataset Users: ", dpl_users.shape[0])
# Out:
# jumlah baris duplikasi dataset Books:  0
# jumlah baris duplikasi dataset Ratings:  0
# jumlah baris duplikasi dataset Users:  0

# %% [markdown]
# ### Periksa Missing value Dataset

# %%
ds_books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ds_ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
ds_users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %% [markdown]
# ### Periksa data unik Dataset

# %%
for fitur in ds_books.columns:
  print(f"\nData unik fitur {fitur}: ")
  print(ds_books[fitur].unique())
# Out:
# Data unik fitur ISBN:
# ['0195153448' '0002005018' '0060973129' ... '006008667X' '0192126040'
#  '0767409752']
#
# Data unik fitur Book-Title:
# ['Classical Mythology' 'Clara Callan' 'Decision in Normandy' ...
#  'Lily Dale : The True Story of the Town that Talks to the Dead'
#  "Republic (World's Classics)"
#  "A Guided Tour of Rene Descartes' Meditations on First Philosophy with Complete Translations of the Meditations by Ronald Rubin"]
#
# Data unik fitur Book-Author:
# ['Mark P. O. Morford' 'Richard Bruce Wright' "Carlo D'Este" ...
#  'David Biggs' 'Teri Sloat' 'Christopher  Biffle']
#
# Data unik fitur Year-Of-Publication:
# [2002 2001 1991 1999 2000 1993 1996 1988 2004 1998 1994 2003 1997 1983
#  1979 1995 1982 1985 1992 1986 1978 1980 1952 1987 1990 1981 1989 1984 0
#  1968 1961 1958 1974 1976 1971 1977 1975 1965 1941 1970 1962 1973 1972
#  1960 1966 1920 1956 1959 1953 1951 1942 1963 1964 1969 1954 1950 1967
#  2005 1957 1940 1937 1955 1946 1936 1930 2011 1925 1948 1943 1947 1945
#  1923 2020 1939 1926 1938 2030 1911 1904 1949 1932 1928 1929 1927 1931
#  1914 2050 1934 1910 1933 1902 1924 1921 1900 2038 2026 1944 1917 1901
#  2010 1908 1906 1935 1806 2021 '2000' '1995' '1999' '2004' '2003' '1990'
#  '1994' '1986' '1989' '2002' '1981' '1993' '1983' '1982' '1976' '1991'
#  '1977' '1998' '1992' '1996' '0' '1997' '2001' '1974' '1968' '1987' '1984'
#  '1988' '1963' '1956' '1970' '1985' '1978' '1973' '1980' '1979' '1975'
#  '1969' '1961' '1965' '1939' '1958' '1950' '1953' '1966' '1971' '1959'
#  '1972' '1955' '1957' '1945' '1960' '1967' '1932' '1924' '1964' '2012'
#  '1911' '1927' '1948' '1962' '2006' '1952' '1940' '1951' '1931' '1954'
#  '2005' '1930' '1941' '1944' 'DK Publishing Inc' '1943' '1938' '1900'
#  '1942' '1923' '1920' '1933' 'Gallimard' '1909' '1946' '2008' '1378'
#  '2030' '1936' '1947' '2011' '2020' '1919' '1949' '1922' '1897' '2024'
#  '1376' '1926' '2037']
#
# Data unik fitur Publisher:
# ['Oxford University Press' 'HarperFlamingo Canada' 'HarperPerennial' ...
#  'Tempo' 'Life Works Books' 'Connaught']
#
# Data unik fitur Image-URL-S:
# ['http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.THUMBZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.THUMBZZZ.jpg']
#
# Data unik fitur Image-URL-M:
# ['http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.MZZZZZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.MZZZZZZZ.jpg']
#
# Data unik fitur Image-URL-L:
# ['http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.LZZZZZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.LZZZZZZZ.jpg']

# %%
for fitur in ds_ratings.columns:
  print(f"\nData unik fitur {fitur}: ")
  print(ds_ratings[fitur].unique())
# Out:
# Data unik fitur User-ID:
# [276725 276726 276727 ... 276709 276721 276723]
#
# Data unik fitur ISBN:
# ['034545104X' '0155061224' '0446520802' ... '0679752714' '0806917695'
#  '05162443314']
#
# Data unik fitur Book-Rating:
# [ 0  5  3  6  8  7 10  9  4  1  2]

# %%
for fitur in ds_users.columns:
  print(f"\nData unik fitur {fitur}: ")
  print(ds_users[fitur].unique())
# Out:
# Data unik fitur User-ID:
# [     1      2      3 ... 278856 278857 278858]
#
# Data unik fitur Location:
# ['nyc, new york, usa' 'stockton, california, usa'
#  'moscow, yukon territory, russia' ... 'sergnano, lombardia, italy'
#  'stranraer, n/a, united kingdom' 'tacoma, washington, united kingdom']
#
# Data unik fitur Age:
# [ nan  18.  17.  61.  26.  14.  25.  19.  46.  55.  32.  24.  20.  34.
#   23.  51.  31.  21.  44.  30.  57.  43.  37.  41.  54.  42.  50.  39.
#   53.  47.  36.  28.  35.  13.  58.  49.  38.  45.  62.  63.  27.  33.
#   29.  66.  40.  15.  60.   0.  79.  22.  16.  65.  59.  48.  72.  56.
#   67.   1.  80.  52.  69.  71.  73.  78.   9.  64. 103. 104.  12.  74.
#   75. 231.   3.  76.  83.  68. 119.  11.  77.   2.  70.  93.   8.   7.
#    4.  81. 114. 230. 239.  10.   5. 148. 151.   6. 101. 201.  96.  84.
#   82.  90. 123. 244. 133.  91. 128.  94.  85. 141. 110.  97. 219.  86.
#  124.  92. 175. 172. 209. 212. 237.  87. 162. 100. 156. 136.  95.  89.
#  106.  99. 108. 210.  88. 199. 147. 168. 132. 159. 186. 152. 102. 116.
#  200. 115. 226. 137. 207. 229. 138. 109. 105. 228. 183. 204.  98. 223.
#  113. 208. 107. 157. 111. 146. 118. 220. 143. 140. 189. 127.]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Untuk dataset Books, dikarenakan kolom `Year-Of-Publication` seharusnya bertipe data numerik karena berkaitan dengan waktu, maka akan diubah tipe data tersebut menjadi numerik

# %%
try:
  ds_books['Year-Of-Publication'] = ds_books['Year-Of-Publication'].astype('int64')
except Exception as e:
  print(e)
# Out:
# invalid literal for int() with base 10: 'DK Publishing Inc'

# %% [markdown]
# terdapat tahun publikasi yang terisi bukan dengan tahun melainkan dengan teks, sehingga perlu penangan agar kolom `Year-Of-Publication` berisikan tipe data numerik

# %%
non_numerik_year_idx = []
for i in range(ds_books.shape[0]):
  try:
    int(ds_books.loc[i, 'Year-Of-Publication'])
  except:
    non_numerik_year_idx.append(np.int64(i))
    print(i)
    # print(ds_books.loc[i, 'Year-Of-Publication'])
# Out:
# 209538
# 220731
# 221678

# %% [markdown]
# Terdapat 3 data yang tahun publikasinya tidak bisa diubah ke tipe data numerik

# %%
ds_books.iloc[non_numerik_year_idx]
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        Book-Author Year-Of-Publication  \
# 209538        2000   DK Publishing Inc
# 220731        2003           Gallimard
# 221678        2000   DK Publishing Inc
#
#                                                 Publisher  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-S  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-M Image-URL-L
# 209538  http://images.amazon.com/images/P/078946697X.0...         NaN
# 220731  http://images.amazon.com/images/P/2070426769.0...         NaN
# 221678  http://images.amazon.com/images/P/0789466953.0...         NaN

# %% [markdown]
# dikarenakan terjadi kesalahan data antara kolom `Book-Author` dan `Year-of-Publication` maka dilakukan pertukaran `value` pada kedua kolom tersebut agar sesuai.

# %%
for idx in non_numerik_year_idx:
  year = ds_books.iloc[idx]['Book-Author']
  author = ds_books.iloc[idx]['Year-Of-Publication']
  ds_books.iloc[idx]['Book-Author'] = author
  ds_books.iloc[idx]['Year-Of-Publication'] = year
ds_books.iloc[non_numerik_year_idx]
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#               Book-Author Year-Of-Publication  \
# 209538  DK Publishing Inc                2000
# 220731          Gallimard                2003
# 221678  DK Publishing Inc                2000
#
#                                                 Publisher  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-S  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-M Image-URL-L
# 209538  http://images.amazon.com/images/P/078946697X.0...         NaN
# 220731  http://images.amazon.com/images/P/2070426769.0...         NaN
# 221678  http://images.amazon.com/images/P/0789466953.0...         NaN

# %% [markdown]
# Kemudian diubah nilai kolom `Year-Of-Publication` ke tipe data numerik

# %%
ds_books['Year-Of-Publication'] = ds_books['Year-Of-Publication'].astype('int64')

# %%
ds_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  int64
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 16.6+ MB

# %%
ds_books_rating = pd.merge(ds_books, ds_ratings, on='ISBN')
ds_books_rating.head()
# Out:
#          ISBN           Book-Title           Book-Author  Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                 2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                 2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                 2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                 2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                 2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L  User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/0195153448.0...        2            0
# 1  http://images.amazon.com/images/P/0002005018.0...        8            5
# 2  http://images.amazon.com/images/P/0002005018.0...    11400            0
# 3  http://images.amazon.com/images/P/0002005018.0...    11676            8
# 4  http://images.amazon.com/images/P/0002005018.0...    41385            0

# %%
ds_books_rating.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            4
# User-ID                0
# Book-Rating            0
# dtype: int64

# %% [markdown]
# Setelah apakah terdapat _missing value_ pada `Dataframe` yang merupakan gabungan antara dataset Books dan Ratings, dengan mengecualikan kolom `Image-URL-L`, maka total data yang memiliki _missing value_ berjumlah 3 sehingga dapat dilakukan _drop_ pada dara tersebut

# %%
ds_books_rating.dropna(inplace=True)
ds_books_rating.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# User-ID                0
# Book-Rating            0
# dtype: int64

# %% [markdown]
# Sekarang dataset sudah bersih dari _missing value_ sehingga dapat dilakukan proses selanjutnya yaitu menggabungkan dataset tersebut dengan dataset Users.

# %%
df = pd.merge(ds_books_rating, ds_users, on='User-ID')
df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L  User-ID  Book-Rating  \
# 0  http://images.amazon.com/images/P/0195153448.0...        2            0
# 1  http://images.amazon.com/images/P/0002005018.0...        8            5
# 2  http://images.amazon.com/images/P/0060973129.0...        8            0
# 3  http://images.amazon.com/images/P/0374157065.0...        8            0
# 4  http://images.amazon.com/images/P/0393045218.0...        8            0
#
#                     Location   Age
# 0  stockton, california, usa  18.0
# 1   timmins, ontario, canada   NaN
# 2   timmins, ontario, canada   NaN
# 3   timmins, ontario, canada   NaN
# 4   timmins, ontario, canada   NaN

# %%
df.isnull().sum()
# Out:
# ISBN                        0
# Book-Title                  0
# Book-Author                 0
# Year-Of-Publication         0
# Publisher                   0
# Image-URL-S                 0
# Image-URL-M                 0
# Image-URL-L                 0
# User-ID                     0
# Book-Rating                 0
# Location                    0
# Age                    277833
# dtype: int64

# %%
df.isna().sum()
# Out:
# ISBN                        0
# Book-Title                  0
# Book-Author                 0
# Year-Of-Publication         0
# Publisher                   0
# Image-URL-S                 0
# Image-URL-M                 0
# Image-URL-L                 0
# User-ID                     0
# Book-Rating                 0
# Location                    0
# Age                    277833
# dtype: int64

# %%
df.drop_duplicates(subset=["Book-Title"], inplace=True)

# %% [markdown]
# Selanjutnya adalah mengubah tipe data non numerik menjadi numerik.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241066 entries, 0 to 1031128
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 241066 non-null  object
#  1   Book-Title           241066 non-null  object
#  2   Book-Author          241066 non-null  object
#  3   Year-Of-Publication  241066 non-null  int64
#  4   Publisher            241066 non-null  object
#  5   Image-URL-S          241066 non-null  object
#  6   Image-URL-M          241066 non-null  object
#  7   Image-URL-L          241066 non-null  object
#  8   User-ID              241066 non-null  int64
#  9   Book-Rating          241066 non-null  int64
#  10  Location             241066 non-null  object
#  11  Age                  176356 non-null  float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 23.9+ MB

# %% [markdown]
# Untuk mempersingkat waktu pelatihan, maka akan dilakukan data sampling pada 9000 data saja

# %%
df = df.sample(n=5000, random_state=3)

# %% [markdown]
# ### Data Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
kolom_obyek = ['ISBN', 'Book-Title', 'Book-Author', 'Publisher', 'Location', 'User-ID']
label_encoders = {
    'ISBN': LabelEncoder(),
    'Book-Title': LabelEncoder(),
    'Book-Author': LabelEncoder(),
    'Publisher': LabelEncoder(),
    'Location': LabelEncoder(),
    'User-ID': LabelEncoder()}
df_encoded = df.copy()
for col in kolom_obyek:
    df_encoded[col] = label_encoders[col].fit_transform(df_encoded[col])
df_encoded.head()
# Out:
#         ISBN  Book-Title  Book-Author  Year-Of-Publication  Publisher  \
# 127112  4214        2491         4058                 1994        833
# 536799  3314        4206         2029                 1991        904
# 79000   1187        3288         1577                 1993        118
# 42186    764        4335         1755                 1985       1043
# 151185  1931        2985          312                 1997        799
#
#                                               Image-URL-S  \
# 127112  http://images.amazon.com/images/P/1569870454.0...
# 536799  http://images.amazon.com/images/P/0816152047.0...
# 79000   http://images.amazon.com/images/P/0380769670.0...
# 42186   http://images.amazon.com/images/P/0345332105.0...
# 151185  http://images.amazon.com/images/P/0515121428.0...
#
#                                               Image-URL-M  \
# 127112  http://images.amazon.com/images/P/1569870454.0...
# 536799  http://images.amazon.com/images/P/0816152047.0...
# 79000   http://images.amazon.com/images/P/0380769670.0...
# 42186   http://images.amazon.com/images/P/0345332105.0...
# 151185  http://images.amazon.com/images/P/0515121428.0...
#
#                                               Image-URL-L  User-ID  \
# 127112  http://images.amazon.com/images/P/1569870454.0...     1851
# 536799  http://images.amazon.com/images/P/0816152047.0...     1053
# 79000   http://images.amazon.com/images/P/0380769670.0...      918
# 42186   http://images.amazon.com/images/P/0345332105.0...      223
# 151185  http://images.amazon.com/images/P/0515121428.0...     2205
#
#         Book-Rating  Location   Age
# 127112            0       525  41.0
# 536799            0       122  60.0
# 79000             0      1411  43.0
# 42186             0      1426  37.0
# 151185            0       971   NaN

# %%
# Mengubah User-ID menjadi list tanpa nilai yang sama
user_ids = df['User-ID'].unique().tolist()
print('list User-ID: ', user_ids)

# Melakukan encoding User-ID
user_to_user_encoded = {x: i for i, x in enumerate(user_ids)}
print('encoded User-ID : ', user_to_user_encoded)

# Melakukan proses encoding angka ke ke User-ID
user_encoded_to_user = {i: x for i, x in enumerate(user_ids)}
print('encoded angka ke User-ID: ', user_encoded_to_user)
# Out:
# list User-ID:  [235842, 128835, 110973, 26544, 278418, 205426, 76626, 212898, 207246, 189334, 153662, 155343, 127359, 55548, 112026, 144131, 178950, 54898, 179772, 79186, 116931, 114868, 235105, 145619, 98707, 110029, 7286, 16795, 99227, 198711, 227447, 190925, 131913, 253198, 185233, 23902, 142974, 28591, 188171, 13896, 107784, 30533, 108285, 143253, 207259, 155916, 38273, 2110, 238557, 230522, 3363, 258534, 110912, 273971, 245827, 56447, 9806, 102967, 234828, 115003, 11676, 22365, 164533, 55492, 185384, 129851
y = df['rating'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
# Membagi menjadi 90% data train dan 10% data validasi
train_indices = int(0.9 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %%
x_train.shape[0], x_val.shape[0]
# Out:
# (4500, 500)

# %% [markdown]
# # Model Development

# %% [markdown]
# ## Collaborative Filtering

# %% [markdown]
# ### Model RecommenderNet

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Flatten,Embedding,Dense,Concatenate

# %%
class RecommenderNet(tf.keras.Model):

  # Insialisasi fungsi
  def __init__(self, num_users, num_isbn, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_isbn = num_isbn
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( # layer embedding user
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) # layer embedding user bias
    self.isbn_embedding = layers.Embedding( # layer embeddings isbn
        num_isbn,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.isbn_bias = layers.Embedding(num_isbn, 1) # layer embedding isbn bias

  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) # memanggil layer embedding 1
    user_bias = self.user_bias(inputs[:, 0]) # memanggil layer embedding 2
    isbn_vector = self.isbn_embedding(inputs[:, 1]) # memanggil layer embedding 3
    isbn_bias = self.isbn_bias(inputs[:, 1]) # memanggil layer embedding 4

    dot_user_isbn = tf.tensordot(user_vector, isbn_vector, 2)

    x = dot_user_isbn + user_bias + isbn_bias

    return tf.nn.sigmoid(x) # activation sigmoid

# %%
# Inisialisasi Model
model = RecommenderNet(num_users, num_isbn, 50)

# %%
# Model compile
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Memulai training
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = 8,
    epochs = 100,
    validation_data = (x_val, y_val)
)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 7s 10ms/step - loss: 0.6879 - root_mean_squared_error: 0.4430 - val_loss: 0.6818 - val_root_mean_squared_error: 0.4353
# Epoch 2/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.6284 - root_mean_squared_error: 0.4084 - val_loss: 0.6714 - val_root_mean_squared_error: 0.4291
# Epoch 3/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5517 - root_mean_squared_error: 0.3644 - val_loss: 0.6644 - val_root_mean_squared_error: 0.4249
# Epoch 4/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.5317 - root_mean_squared_error: 0.3540 - val_loss: 0.6582 - val_root_mean_squared_error: 0.4213
# Epoch 5/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.5147 - root_mean_squared_error: 0.3445 - val_loss: 0.6521 - val_root_mean_squared_error: 0.4177
# Epoch 6/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.5005 - root_mean_squared_error: 0.3361 - val_loss: 0.6460 - val_root_mean_squared_error: 0.4142
# Epoch 7/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4841 - root_mean_squared_error: 0.3267 - val_loss: 0.6401 - val_root_mean_squared_error: 0.4108
# Epoch 8/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4719 - root_mean_squared_error: 0.3185 - val_loss: 0.6343 - val_root_mean_squared_error: 0.4074
# Epoch 9/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4593 - root_mean_squared_error: 0.3113 - val_loss: 0.6291 - val_root_mean_squared_error: 0.4045
# Epoch 10/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4501 - root_mean_squared_error: 0.3054 - val_loss: 0.6242 - val_root_mean_squared_error: 0.4017
# Epoch 11/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4380 - root_mean_squared_error: 0.2975 - val_loss: 0.6195 - val_root_mean_squared_error: 0.3991
# Epoch 12/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.4274 - root_mean_squared_error: 0.2908 - val_loss: 0.6150 - val_root_mean_squared_error: 0.3966
# Epoch 13/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4162 - root_mean_squared_error: 0.2839 - val_loss: 0.6109 - val_root_mean_squared_error: 0.3944
# Epoch 14/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4089 - root_mean_squared_error: 0.2787 - val_loss: 0.6068 - val_root_mean_squared_error: 0.3922
# Epoch 15/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3991 - root_mean_squared_error: 0.2716 - val_loss: 0.6029 - val_root_mean_squared_error: 0.3901
# Epoch 16/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.3929 - root_mean_squared_error: 0.2680 - val_loss: 0.5995 - val_root_mean_squared_error: 0.3884
# Epoch 17/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.3828 - root_mean_squared_error: 0.2602 - val_loss: 0.5961 - val_root_mean_squared_error: 0.3866
# Epoch 18/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3771 - root_mean_squared_error: 0.2559 - val_loss: 0.5929 - val_root_mean_squared_error: 0.3849
# Epoch 19/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3687 - root_mean_squared_error: 0.2496 - val_loss: 0.5894 - val_root_mean_squared_error: 0.3831
# Epoch 20/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3621 - root_mean_squared_error: 0.2453 - val_loss: 0.5866 - val_root_mean_squared_error: 0.3817
# Epoch 21/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.3559 - root_mean_squared_error: 0.2402 - val_loss: 0.5838 - val_root_mean_squared_error: 0.3803
# Epoch 22/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.3467 - root_mean_squared_error: 0.2326 - val_loss: 0.5813 - val_root_mean_squared_error: 0.3791
# Epoch 23/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.3433 - root_mean_squared_error: 0.2309 - val_loss: 0.5788 - val_root_mean_squared_error: 0.3778
# Epoch 24/100
# 563/563 [==============================] - 7s 12ms/step - loss: 0.3353 - root_mean_squared_error: 0.2245 - val_loss: 0.5766 - val_root_mean_squared_error: 0.3768
# Epoch 25/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.3322 - root_mean_squared_error: 0.2213 - val_loss: 0.5745 - val_root_mean_squared_error: 0.3757
# Epoch 26/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3271 - root_mean_squared_error: 0.2171 - val_loss: 0.5721 - val_root_mean_squared_error: 0.3746
# Epoch 27/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.3214 - root_mean_squared_error: 0.2121 - val_loss: 0.5701 - val_root_mean_squared_error: 0.3737
# Epoch 28/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.3166 - root_mean_squared_error: 0.2081 - val_loss: 0.5681 - val_root_mean_squared_error: 0.3727
# Epoch 29/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.3114 - root_mean_squared_error: 0.2035 - val_loss: 0.5663 - val_root_mean_squared_error: 0.3719
# Epoch 30/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.3058 - root_mean_squared_error: 0.1992 - val_loss: 0.5645 - val_root_mean_squared_error: 0.3711
# Epoch 31/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3040 - root_mean_squared_error: 0.1972 - val_loss: 0.5628 - val_root_mean_squared_error: 0.3703
# Epoch 32/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2989 - root_mean_squared_error: 0.1930 - val_loss: 0.5612 - val_root_mean_squared_error: 0.3696
# Epoch 33/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2935 - root_mean_squared_error: 0.1880 - val_loss: 0.5599 - val_root_mean_squared_error: 0.3690
# Epoch 34/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2882 - root_mean_squared_error: 0.1832 - val_loss: 0.5585 - val_root_mean_squared_error: 0.3684
# Epoch 35/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2861 - root_mean_squared_error: 0.1817 - val_loss: 0.5571 - val_root_mean_squared_error: 0.3678
# Epoch 36/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2802 - root_mean_squared_error: 0.1759 - val_loss: 0.5557 - val_root_mean_squared_error: 0.3672
# Epoch 37/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2776 - root_mean_squared_error: 0.1739 - val_loss: 0.5544 - val_root_mean_squared_error: 0.3666
# Epoch 38/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2757 - root_mean_squared_error: 0.1724 - val_loss: 0.5534 - val_root_mean_squared_error: 0.3662
# Epoch 39/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2712 - root_mean_squared_error: 0.1676 - val_loss: 0.5525 - val_root_mean_squared_error: 0.3659
# Epoch 40/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.2702 - root_mean_squared_error: 0.1667 - val_loss: 0.5514 - val_root_mean_squared_error: 0.3655
# Epoch 41/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2649 - root_mean_squared_error: 0.1610 - val_loss: 0.5505 - val_root_mean_squared_error: 0.3651
# Epoch 42/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.2624 - root_mean_squared_error: 0.1589 - val_loss: 0.5496 - val_root_mean_squared_error: 0.3648
# Epoch 43/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2588 - root_mean_squared_error: 0.1562 - val_loss: 0.5489 - val_root_mean_squared_error: 0.3645
# Epoch 44/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2567 - root_mean_squared_error: 0.1537 - val_loss: 0.5480 - val_root_mean_squared_error: 0.3642
# Epoch 45/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2540 - root_mean_squared_error: 0.1515 - val_loss: 0.5471 - val_root_mean_squared_error: 0.3638
# Epoch 46/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.2521 - root_mean_squared_error: 0.1491 - val_loss: 0.5463 - val_root_mean_squared_error: 0.3635
# Epoch 47/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2477 - root_mean_squared_error: 0.1443 - val_loss: 0.5453 - val_root_mean_squared_error: 0.3631
# Epoch 48/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2467 - root_mean_squared_error: 0.1440 - val_loss: 0.5448 - val_root_mean_squared_error: 0.3629
# Epoch 49/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2434 - root_mean_squared_error: 0.1403 - val_loss: 0.5443 - val_root_mean_squared_error: 0.3628
# Epoch 50/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2407 - root_mean_squared_error: 0.1367 - val_loss: 0.5436 - val_root_mean_squared_error: 0.3625
# Epoch 51/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2381 - root_mean_squared_error: 0.1352 - val_loss: 0.5432 - val_root_mean_squared_error: 0.3624
# Epoch 52/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2356 - root_mean_squared_error: 0.1314 - val_loss: 0.5424 - val_root_mean_squared_error: 0.3621
# Epoch 53/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2347 - root_mean_squared_error: 0.1323 - val_loss: 0.5424 - val_root_mean_squared_error: 0.3622
# Epoch 54/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2319 - root_mean_squared_error: 0.1274 - val_loss: 0.5415 - val_root_mean_squared_error: 0.3618
# Epoch 55/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2286 - root_mean_squared_error: 0.1243 - val_loss: 0.5413 - val_root_mean_squared_error: 0.3617
# Epoch 56/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2278 - root_mean_squared_error: 0.1234 - val_loss: 0.5410 - val_root_mean_squared_error: 0.3617
# Epoch 57/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.2267 - root_mean_squared_error: 0.1222 - val_loss: 0.5406 - val_root_mean_squared_error: 0.3615
# Epoch 58/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2238 - root_mean_squared_error: 0.1185 - val_loss: 0.5401 - val_root_mean_squared_error: 0.3613
# Epoch 59/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2242 - root_mean_squared_error: 0.1209 - val_loss: 0.5399 - val_root_mean_squared_error: 0.3613
# Epoch 60/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2214 - root_mean_squared_error: 0.1160 - val_loss: 0.5395 - val_root_mean_squared_error: 0.3612
# Epoch 61/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2208 - root_mean_squared_error: 0.1164 - val_loss: 0.5394 - val_root_mean_squared_error: 0.3612
# Epoch 62/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2167 - root_mean_squared_error: 0.1106 - val_loss: 0.5390 - val_root_mean_squared_error: 0.3610
# Epoch 63/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2151 - root_mean_squared_error: 0.1095 - val_loss: 0.5388 - val_root_mean_squared_error: 0.3609
# Epoch 64/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.2152 - root_mean_squared_error: 0.1100 - val_loss: 0.5384 - val_root_mean_squared_error: 0.3608
# Epoch 65/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.2135 - root_mean_squared_error: 0.1067 - val_loss: 0.5383 - val_root_mean_squared_error: 0.3608
# Epoch 66/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2114 - root_mean_squared_error: 0.1049 - val_loss: 0.5383 - val_root_mean_squared_error: 0.3608
# Epoch 67/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2104 - root_mean_squared_error: 0.1036 - val_loss: 0.5381 - val_root_mean_squared_error: 0.3607
# Epoch 68/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2086 - root_mean_squared_error: 0.1013 - val_loss: 0.5382 - val_root_mean_squared_error: 0.3608
# Epoch 69/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2071 - root_mean_squared_error: 0.0982 - val_loss: 0.5378 - val_root_mean_squared_error: 0.3606
# Epoch 70/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2067 - root_mean_squared_error: 0.0987 - val_loss: 0.5376 - val_root_mean_squared_error: 0.3605
# Epoch 71/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2049 - root_mean_squared_error: 0.0969 - val_loss: 0.5376 - val_root_mean_squared_error: 0.3606
# Epoch 72/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2045 - root_mean_squared_error: 0.0965 - val_loss: 0.5376 - val_root_mean_squared_error: 0.3606
# Epoch 73/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2031 - root_mean_squared_error: 0.0953 - val_loss: 0.5376 - val_root_mean_squared_error: 0.3606
# Epoch 74/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2011 - root_mean_squared_error: 0.0916 - val_loss: 0.5378 - val_root_mean_squared_error: 0.3607
# Epoch 75/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2002 - root_mean_squared_error: 0.0900 - val_loss: 0.5379 - val_root_mean_squared_error: 0.3608
# Epoch 76/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.1988 - root_mean_squared_error: 0.0883 - val_loss: 0.5378 - val_root_mean_squared_error: 0.3607
# Epoch 77/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.1980 - root_mean_squared_error: 0.0884 - val_loss: 0.5380 - val_root_mean_squared_error: 0.3608
# Epoch 78/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.1970 - root_mean_squared_error: 0.0862 - val_loss: 0.5381 - val_root_mean_squared_error: 0.3609
# Epoch 79/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.1958 - root_mean_squared_error: 0.0846 - val_loss: 0.5381 - val_root_mean_squared_error: 0.3609
# Epoch 80/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.1952 - root_mean_squared_error: 0.0838 - val_loss: 0.5382 - val_root_mean_squared_error: 0.3609
# Epoch 81/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1943 - root_mean_squared_error: 0.0835 - val_loss: 0.5384 - val_root_mean_squared_error: 0.3610
# Epoch 82/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.1926 - root_mean_squared_error: 0.0798 - val_loss: 0.5385 - val_root_mean_squared_error: 0.3610
# Epoch 83/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.1926 - root_mean_squared_error: 0.0823 - val_loss: 0.5386 - val_root_mean_squared_error: 0.3610
# Epoch 84/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1917 - root_mean_squared_error: 0.0792 - val_loss: 0.5385 - val_root_mean_squared_error: 0.3609
# Epoch 85/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.1903 - root_mean_squared_error: 0.0783 - val_loss: 0.5389 - val_root_mean_squared_error: 0.3611
# Epoch 86/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1890 - root_mean_squared_error: 0.0749 - val_loss: 0.5391 - val_root_mean_squared_error: 0.3612
# Epoch 87/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1890 - root_mean_squared_error: 0.0762 - val_loss: 0.5392 - val_root_mean_squared_error: 0.3612
# Epoch 88/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.1881 - root_mean_squared_error: 0.0739 - val_loss: 0.5393 - val_root_mean_squared_error: 0.3612
# Epoch 89/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1865 - root_mean_squared_error: 0.0716 - val_loss: 0.5397 - val_root_mean_squared_error: 0.3613
# Epoch 90/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.1863 - root_mean_squared_error: 0.0717 - val_loss: 0.5400 - val_root_mean_squared_error: 0.3614
# Epoch 91/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.1855 - root_mean_squared_error: 0.0706 - val_loss: 0.5403 - val_root_mean_squared_error: 0.3615
# Epoch 92/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.1851 - root_mean_squared_error: 0.0703 - val_loss: 0.5405 - val_root_mean_squared_error: 0.3616
# Epoch 93/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.1840 - root_mean_squared_error: 0.0679 - val_loss: 0.5405 - val_root_mean_squared_error: 0.3615
# Epoch 94/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1833 - root_mean_squared_error: 0.0675 - val_loss: 0.5407 - val_root_mean_squared_error: 0.3616
# Epoch 95/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1831 - root_mean_squared_error: 0.0671 - val_loss: 0.5409 - val_root_mean_squared_error: 0.3616
# Epoch 96/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.1818 - root_mean_squared_error: 0.0647 - val_loss: 0.5409 - val_root_mean_squared_error: 0.3615
# Epoch 97/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.1814 - root_mean_squared_error: 0.0632 - val_loss: 0.5410 - val_root_mean_squared_error: 0.3614
# Epoch 98/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.1808 - root_mean_squared_error: 0.0642 - val_loss: 0.5411 - val_root_mean_squared_error: 0.3614
# Epoch 99/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.1802 - root_mean_squared_error: 0.0624 - val_loss: 0.5414 - val_root_mean_squared_error: 0.3615
# Epoch 100/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.1798 - root_mean_squared_error: 0.0627 - val_loss: 0.5414 - val_root_mean_squared_error: 0.3614

# %%
model.summary()
# Out:
# Model: "recommender_net_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     multiple                  110350
#
#  embedding_5 (Embedding)     multiple                  2207
#
#  embedding_6 (Embedding)     multiple                  250000
#
#  embedding_7 (Embedding)     multiple                  5000
#
# =================================================================
# Total params: 367,557
# Trainable params: 367,557
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Evaluasi Model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Evaluasi nilai RMSE model
_, rmse = model.evaluate(x_val, y_val)
print('RMSE:', rmse)
# Out:
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5414 - root_mean_squared_error: 0.3614
# RMSE: 0.361360102891922

# %% [markdown]
# # Inference Model untuk memberikan rekomendasi buku

# %%
# Mengambil sample user
user_id = df['User-ID'].sample(1).iloc[0]
isbn_rated_by_user = df[df['User-ID'] == user_id]
print(user_id)
# Out:
# 2977

# %%
isbn_rated_by_user
# Out:
#              ISBN                     Book-Title          Book-Author  \
# 33268  0553207628    History of Women In America       Carol Hymowitz
# 33337  1573225681   Living Buddha, Living Christ      Thich Nhat Hanh
# 33334  0933932669          The Sadness of Christ          Thomas More
# 33309  0140441077  The Prince (Penguin Classics)  Niccolo Machiavelli
#
#        Year-Of-Publication                 Publisher  \
# 33268                    0     Bantam Doubleday Dell
# 33337                 1997           Riverhead Books
# 33334                 1997  Scepter Publishers, Inc.
# 33309                 1961             Penguin Books
#
#                                              Image-URL-S  \
# 33268  http://images.amazon.com/images/P/0553207628.0...
# 33337  http://images.amazon.com/images/P/1573225681.0...
# 33334  http://images.amazon.com/images/P/0933932669.0...
# 33309  http://images.amazon.com/images/P/0140441077.0...
#
#                                              Image-URL-M  \
# 33268  http://images.amazon.com/images/P/0553207628.0...
# 33337  http://images.amazon.com/images/P/1573225681.0...
# 33334  http://images.amazon.com/images/P/0933932669.0...
# 33309  http://images.amazon.com/images/P/0140441077.0...
#
#                                              Image-URL-L  User-ID  \
# 33268  http://images.amazon.com/images/P/0553207628.0...     2977
# 33337  http://images.amazon.com/images/P/1573225681.0...     2977
# 33334  http://images.amazon.com/images/P/0933932669.0...     2977
# 33309  http://images.amazon.com/images/P/0140441077.0...     2977
#
#        Book-Rating                   Location   Age  user  isbn  rating
# 33268            0  richland, washington, usa  25.0   479   651     0.0
# 33337            8  richland, washington, usa  25.0   479  4357     8.0
# 33334            0  richland, washington, usa  25.0   479  4386     0.0
# 33309            0  richland, washington, usa  25.0   479  4767     0.0

# %%
isbn_not_rated = ds_books[~ds_books['ISBN'].isin(isbn_rated_by_user['ISBN'].values)]['ISBN']
isbn_not_rated = list(
    set(isbn_not_rated)
    .intersection(set(isbn_to_isbn_encoded.keys()))
)

isbn_not_rated = [[isbn_to_isbn_encoded.get(x)] for x in isbn_not_rated]
user_encoder = user_to_user_encoded.get(user_id)
user_isbn_array = np.hstack(
    ([[user_encoder]] * len(isbn_not_rated), isbn_not_rated)
)

# %%
ratings = model.predict(user_isbn_array).flatten()

top_ratings_indices = ratings.argsort()[-10:][::-1]
recommended_isbn_ids = [
    isbn_encoded_to_isbn.get(isbn_not_rated[x][0]) for x in top_ratings_indices
]

print('Menampilkan daftar rekomendasi untuk pengguna dengan id: {}'.format(user_id))
print('===' * 9)
print('Buku dengan rating yang tinggi dari pengguna')
print('----' * 8)

top_isbn_user = (
    isbn_rated_by_user.sort_values(
        by = 'rating',
        ascending=False
    )
    .head(5)
    .ISBN.values
)

isbn_df_rows = ds_books[ds_books['ISBN'].isin(top_isbn_user)]
for row in isbn_df_rows.itertuples():
    print(f"{row.ISBN} - Judul: {row._2} - Author: {row._3}")

print('----' * 8)
print('Top 10 Book recommendation')
print('----' * 8)

recommended_isbn = ds_books[ds_books['ISBN'].isin(recommended_isbn_ids)]
for row in recommended_isbn.itertuples():
    print(f"{row.ISBN} - Judul: {row._2} Author: {row._3}")
# Out:
# 157/157 [==============================] - 0s 3ms/step
# Menampilkan daftar rekomendasi untuk pengguna dengan id: 2977
# ===========================
# Buku dengan rating yang tinggi dari pengguna
# --------------------------------
# 0553207628 - Judul: History of Women In America - Author: Carol Hymowitz
# 0140441077 - Judul: The Prince (Penguin Classics) - Author: Niccolo Machiavelli
# 0933932669 - Judul: The Sadness of Christ - Author: Thomas More
# 1573225681 - Judul: Living Buddha, Living Christ - Author: Thich Nhat Hanh
# --------------------------------
# Top 10 Book recommendation
# --------------------------------
# 3404128753 - Judul: Der Schatten des Herrn. Author: John F. Case
# 031298670X - Judul: Elliott Roosevelt's Murder at the President's Door : An Eleanor Roosevelt Mystery (An Eleanor Roosevelt Mystery) Author: Elliott Roosevelt
# 0425174336 - Judul: Crimson Stain Author: Jim Fisher
# 0736905588 - Judul: The Proposal: Book 1 (The English Garden Series) Author: Lori Wick
# 0201518015 - Judul: Husband Is the Past Tense of Daddy: And Other Dispatches from the Front Lines of Motherhood Author: Teryl Zarnow
# 0310904102 - Judul: Comparative Study Bible Author: Not Applicable (Na )
# 1854060627 - Judul: Baby Apatosaurus Author: Dick Dudley
# 0679808477 - Judul: The Berenstain Bears and the Prize Pumpkin (First Time Books) Author: STAN BERENSTAIN
# 0140439161 - Judul: The Bounty Mutiny (Penguin Classics) Author: William Bligh
# 0553379925 - Judul: Caring for Your School Age Child : Ages 5-12 Author: EDWARD L. SCHOR
